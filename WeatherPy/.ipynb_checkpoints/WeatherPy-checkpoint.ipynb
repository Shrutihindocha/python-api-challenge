# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

from api_keys import g_key
from api_keys import weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
import random
from citipy import citipy

#using random function to create uniform lat and lng ranges
lat = [random.uniform(-90,90) for x in range(2500)] #lat range (-90 to 90deg)
lng = [random.uniform(-180,180) for x in range(2500)] #lng range (-180 to 180deg)

coords = zip(lat,lng)

cities =[] #creating empty set

# cities

for coord in coords:
        city = citipy.nearest_city(coord[0],coord[1]).city_name
        if city not in cities:
            cities.append(city)

print(f"The list city has {len(cities)} cities")

# print(cities) ##testing
# Out:
# The list city has 881 cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#forming dataframe
df_cities = pd.DataFrame({"City":cities})

df_cities
# Out:
#             City
# 0         atuona
# 1     miles city
# 2        vaitupu
# 3         kampot
# 4          kuche
# ..           ...
# 692    alyangula
# 693    fairbanks
# 694     kingaroy
# 695  san quintin
# 696     havelock
#
# [697 rows x 1 columns]

# %%
#API request
from pprint import pprint

base_url = f"http://api.openweathermap.org/data/2.5/weather"

print("Beginning Data Retrival")
print("--------------------------------")

for index, row in df_cities.iterrows():
    
    parameters = {
    "q":row["City"],
    "appid": weather_api_key,
    "units": "imperial"
    }
    
    try:
        response_data = requests.get(base_url, params=parameters).json()
        
         #Adding latitude to DF
        df_cities.loc[index, "Lat"]= response_data["coord"]["lat"]
        df_cities.loc[index, "Lng"]= response_data["coord"]["lon"]
        df_cities.loc[index, "Max Temp"]= response_data["main"]["temp_max"]
        df_cities.loc[index, "Humidity"]= float(response_data["main"]["humidity"])
        df_cities.loc[index, "Cloudiness"]= response_data["clouds"]["all"]
        df_cities.loc[index, "Wind Speed"]= response_data["wind"]["speed"]
        df_cities.loc[index, "Country"]= response_data["sys"]["country"]
        df_cities.loc[index, "Date"]= response_data["dt"]
                
        record = index + 1
        set_no = int(index/50)+1
        
        print(f"Processing Record {record} of Set {set_no} | {response_data['name']}")
        
    except KeyError:
        print(f"\n City not found. Skipping... \n")
        pass
    
print("--------------------------------")
print("Data Retrieval Complete")
print("--------------------------------")
# Out:
# Beginning Data Retrival
# --------------------------------
# Processing Record 1 of Set 1 | Atuona
# Processing Record 2 of Set 1 | Miles City
#
#  City not found. Skipping...
#
# Processing Record 4 of Set 1 | Kampot
#
#  City not found. Skipping...
#
# Processing Record 6 of Set 1 | Staryy Nadym
# Processing Record 7 of Set 1 | Busselton
# Processing Record 8 of Set 1 | Avarua
# Processing Record 9 of Set 1 | Rikitea
# Processing Record 10 of Set 1 | Tuktoyaktuk
# Processing Record 11 of Set 1 | Kaitangata
# Processing Record 12 of Set 1 | Neuquén
# Processing Record 13 of Set 1 | Belle Fourche
# Processing Record 14 of Set 1 | Ushuaia
# Processing Record 15 of Set 1 | New Norfolk
# Processing Record 16 of Set 1 | Laguna
#
#  City not found. Skipping...
#
# Processing Record 18 of Set 1 | Itoman
# Processing Record 19 of Set 1 | Ponta do Sol
#
#  City not found. Skipping...
#
#
#  City not found. Skipping...
#
# Processing Record 22 of Set 1 | Vaini
# Processing Record 23 of Set 1 | Saint Anthony
# Processing Record 24 of Set 1 | Kenai
# Processing Record 25 of Set 1 | Ipixuna
# Processing Record 26 of Set 1 | São Filipe
# Processing Record 27 of Set 1 | Jamestown
# Processing Record 28 of Set 1 | Nanortalik
# Processing Record 29 of Set 1 | Ilhabela
# Processing Record 30 of Set 1 | Praia
# Processing Record 31 of Set 1 | Bethel
# Processing Record 32 of Set 1 | Los Llanos de Aridane
# Processing Record 33 of Set 1 | Ishigaki
# Processing Record 34 of Set 1 | Barrow
# Processing Record 35 of Set 1 | Villa Rica
# Processing Record 36 of Set 1 | Quang Ngai
# Processing Record 37 of Set 1 | Newala
# Processing Record 38 of Set 1 | Hermanus
# Processing Record 39 of Set 1 | Saskylakh
# Processing Record 40 of Set 1 | Natchitoches
# Processing Record 41 of Set 1 | Raudeberg
# Processing Record 42 of Set 1 | Pyu
# Processing Record 43 of Set 1 | Iisalmi
# Processing Record 44 of Set 1 | Mezen'
# Processing Record 45 of Set 1 | Samaná
# Processing Record 46 of Set 1 | Port Keats
#
#  City not found. Skipping...
#
# Processing Record 48 of Set 1 | Saint-Philippe
# Processing Record 49 of Set 1 | Carutapera
# Processing Record 50 of Set 1 | Albany
# Processing Record 51 of Set 2 | Punta Arenas
#
#  City not found. Skipping...
#
# Processing Record 53 of Set 2 | Marawi
#
#  City not found. Skipping...
#
#
#  City not found. Skipping...
#
# Processing Record 56 of Set 2 | East London
# Processing Record 57 of Set 2 | Goderich
# Processing Record 58 of Set 2 | Senador José Porfírio
#
#  City not found. Skipping...
#
# Processing Record 60 of Set 2 | The Valley
# Processing Record 61 of Set 2 | Pierre
# Processing Record 62 of Set 2 | Kapaa
#
#  City not found. Skipping...
#
# Processing Record 64 of Set 2 | Saldanha
# Processing Record 65 of Set 2 | Bolton
# Processing Record 66 of Set 2 | Marzuq
# Processing Record 67 of Set 2 | Bima
# Processing Record 68 of Set 2 | Castro
# Processing Record 69 of Set 2 | Mataura
# Processing Record 70 of Set 2 | Zaozyornoye
# Processing Record 71 of Set 2 | Mēga
# Processing Record 72 of Set 2 | Talara
# Processing Record 73 of Set 2 | Chokurdakh
# Processing Record 74 of Set 2 | Cape Town
# Processing Record 75 of Set 2 | Port Hardy
# Processing Record 76 of Set 2 | Natal
# Processing Record 77 of Set 2 | Lavrentiya
# Processing Record 78 of Set 2 | Lompoc
# Processing Record 79 of Set 2 | Sitka
# Processing Record 80 of Set 2 | Moree
# Processing Record 81 of Set 2 | Airai
# Processing Record 82 of Set 2 | Narsaq
#
#  City not found. Skipping...
#
# Processing Record 84 of Set 2 | Provideniya
# Processing Record 85 of Set 2 | Dalbandin
# Processing Record 86 of Set 2 | Port Blair
# Processing Record 87 of Set 2 | Jiaocheng
#
#  City not found. Skipping...
#
# Processing Record 89 of Set 2 | Pevek
# Processing Record 90 of Set 2 | Chui
# Processing Record 91 of Set 2 | Nova Odessa
# Processing Record 92 of Set 2 | Richards Bay
# Processing Record 93 of Set 2 | Grand Haven
# Processing Record 94 of Set 2 | Luanda
# Processing Record 95 of Set 2 | La Ronge
# Processing Record 96 of Set 2 | Mar del Plata
# Processing Record 97 of Set 2 | Preobrazheniye
# Processing Record 98 of Set 2 | Bredasdorp
# Processing Record 99 of Set 2 | Puerto Ayora
# Processing Record 100 of Set 2 | Luau
# Processing Record 101 of Set 3 | Aklavik
# Processing Record 102 of Set 3 | Port Alfred
# Processing Record 103 of Set 3 | Hofn
# Processing Record 104 of Set 3 | Kurayoshi
# Processing Record 105 of Set 3 | Margate
# Processing Record 106 of Set 3 | Ribeira Grande
# Processing Record 107 of Set 3 | Krasnosel'kup
# Processing Record 108 of Set 3 | Saint-Joseph
# Processing Record 109 of Set 3 | Piney Green
# Processing Record 110 of Set 3 | Butaritari
# Processing Record 111 of Set 3 | Tsogni
#
#  City not found. Skipping...
#
# Processing Record 113 of Set 3 | Bluff
# Processing Record 114 of Set 3 | Pudozh
# Processing Record 115 of Set 3 | Andra
# Processing Record 116 of Set 3 | Bengkulu
# Processing Record 117 of Set 3 | Hilo
# Processing Record 118 of Set 3 | Koryazhma
# Processing Record 119 of Set 3 | Leningradskiy
#
#  City not found. Skipping...
#
# Processing Record 121 of Set 3 | Altamira
# Processing Record 122 of Set 3 | Rocha
# Processing Record 123 of Set 3 | Nuuk
# Processing Record 124 of Set 3 | Hobart
# Processing Record 125 of Set 3 | Okhotsk
# Processing Record 126 of Set 3 | Yellowknife
# Processing Record 127 of Set 3 | Matara
# Processing Record 128 of Set 3 | Lamu
# Processing Record 129 of Set 3 | Vardø
# Processing Record 130 of Set 3 | Norman Wells
# Processing Record 131 of Set 3 | Tel Aviv-Yafo
# Processing Record 132 of Set 3 | Kahului
# Processing Record 133 of Set 3 | Arraial do Cabo
# Processing Record 134 of Set 3 | Hithadhoo
# Processing Record 135 of Set 3 | Nieuw Nickerie
# Processing Record 136 of Set 3 | Moose Factory
# Processing Record 137 of Set 3 | Anadyr
# Processing Record 138 of Set 3 | Nikolskoye
# Processing Record 139 of Set 3 | Tombouctou
# Processing Record 140 of Set 3 | Codrington
# Processing Record 141 of Set 3 | Māngrol
# Processing Record 142 of Set 3 | Pochutla
# Processing Record 143 of Set 3 | Bendigo
# Processing Record 144 of Set 3 | Coyhaique
# Processing Record 145 of Set 3 | Jijiang
# Processing Record 146 of Set 3 | Buala
# Processing Record 147 of Set 3 | Palmer
# Processing Record 148 of Set 3 | Lüderitz
# Processing Record 149 of Set 3 | Tual
# Processing Record 150 of Set 3 | Puerto del Rosario
# Processing Record 151 of Set 4 | Haines Junction
# Processing Record 152 of Set 4 | San Fernando del Valle de Catamarca
# Processing Record 153 of Set 4 | Liverpool
# Processing Record 154 of Set 4 | Hailar
# Processing Record 155 of Set 4 | Le Port
#
#  City not found. Skipping...
#
# Processing Record 157 of Set 4 | Upernavik
# Processing Record 158 of Set 4 | Mucurapo
# Processing Record 159 of Set 4 | Qaanaaq
# Processing Record 160 of Set 4 | Torbay
# Processing Record 161 of Set 4 | Qui Nhon
# Processing Record 162 of Set 4 | Coquimbo
# Processing Record 163 of Set 4 | San Juan
# Processing Record 164 of Set 4 | Poya
# Processing Record 165 of Set 4 | Middelburg
# Processing Record 166 of Set 4 | Beringovskiy
# Processing Record 167 of Set 4 | Juradó
# Processing Record 168 of Set 4 | Xingyi
# Processing Record 169 of Set 4 | Río Gallegos
# Processing Record 170 of Set 4 | Bīrpur
# Processing Record 171 of Set 4 | Horsham
# Processing Record 172 of Set 4 | Bururi Province
# Processing Record 173 of Set 4 | Nabire
# Processing Record 174 of Set 4 | Tura
# Processing Record 175 of Set 4 | Tevaitoa
# Processing Record 176 of Set 4 | Urdoma
# Processing Record 177 of Set 4 | Sept-Îles
# Processing Record 178 of Set 4 | Mahébourg
# Processing Record 179 of Set 4 | Cayenne
# Processing Record 180 of Set 4 | Izhma
# Processing Record 181 of Set 4 | Ajdabiya
#
#  City not found. Skipping...
#
#
#  City not found. Skipping...
#
# Processing Record 184 of Set 4 | George Town
# Processing Record 185 of Set 4 | Westport
# Processing Record 186 of Set 4 | Nioro
# Processing Record 187 of Set 4 | Shakawe
# Processing Record 188 of Set 4 | Dikson
# Processing Record 189 of Set 4 | Muisne
# Processing Record 190 of Set 4 | Esperance
# Processing Record 191 of Set 4 | Tasiilaq
# Processing Record 192 of Set 4 | Yar-Sale
# Processing Record 193 of Set 4 | Bandarbeyla
# Processing Record 194 of Set 4 | Eyl
# Processing Record 195 of Set 4 | Mount Gambier
# Processing Record 196 of Set 4 | Katsuura
# Processing Record 197 of Set 4 | Chengdu
# Processing Record 198 of Set 4 | Saint Paul Harbor
# Processing Record 199 of Set 4 | Mossamedes
# Processing Record 200 of Set 4 | Pristina
# Processing Record 201 of Set 5 | Edson
# Processing Record 202 of Set 5 | Pisco
# Processing Record 203 of Set 5 | Chanute
# Processing Record 204 of Set 5 | Eravur
# Processing Record 205 of Set 5 | Barcelona
#
#  City not found. Skipping...
#
# Processing Record 207 of Set 5 | Guider
# Processing Record 208 of Set 5 | Thompson
# Processing Record 209 of Set 5 | Longyearbyen
# Processing Record 210 of Set 5 | Kiryat Gat
# Processing Record 211 of Set 5 | Lokosovo
# Processing Record 212 of Set 5 | Guerrero Negro
# Processing Record 213 of Set 5 | Lebu
# Processing Record 214 of Set 5 | Cabo San Lucas
# Processing Record 215 of Set 5 | Barcs
# Processing Record 216 of Set 5 | Skopin
# Processing Record 217 of Set 5 | Būkān
# Processing Record 218 of Set 5 | Ust-Tsilma
# Processing Record 219 of Set 5 | Zhanakorgan
# Processing Record 220 of Set 5 | Marion
# Processing Record 221 of Set 5 | Grand Forks
# Processing Record 222 of Set 5 | Buchanan
# Processing Record 223 of Set 5 | Ibanda
# Processing Record 224 of Set 5 | Pemangkat
# Processing Record 225 of Set 5 | Kavieng
# Processing Record 226 of Set 5 | Kedrovka
# Processing Record 227 of Set 5 | Ilulissat
# Processing Record 228 of Set 5 | Saint Simons
# Processing Record 229 of Set 5 | Derzhavīnsk
# Processing Record 230 of Set 5 | Hong Kong
# Processing Record 231 of Set 5 | Chernyshevskiy
# Processing Record 232 of Set 5 | Channel-Port aux Basques
# Processing Record 233 of Set 5 | Kruisfontein
# Processing Record 234 of Set 5 | Iqaluit
# Processing Record 235 of Set 5 | Khatanga
# Processing Record 236 of Set 5 | Khrebtovaya
# Processing Record 237 of Set 5 | Bathsheba
# Processing Record 238 of Set 5 | Chany
#
#  City not found. Skipping...
#
# Processing Record 240 of Set 5 | Tucumã
# Processing Record 241 of Set 5 | Doha
# Processing Record 242 of Set 5 | Corrales
# Processing Record 243 of Set 5 | Batticaloa
# Processing Record 244 of Set 5 | Hue
# Processing Record 245 of Set 5 | Esqueda
# Processing Record 246 of Set 5 | Saraza
# Processing Record 247 of Set 5 | Carnarvon
# Processing Record 248 of Set 5 | Turaif
# Processing Record 249 of Set 5 | La Salle
# Processing Record 250 of Set 5 | Cherskiy
# Processing Record 251 of Set 6 | Kamina
# Processing Record 252 of Set 6 | Flinders
# Processing Record 253 of Set 6 | Novoagansk
# Processing Record 254 of Set 6 | Cosalá
# Processing Record 255 of Set 6 | Mwense
# Processing Record 256 of Set 6 | Mechanicsville
# Processing Record 257 of Set 6 | Isangel
# Processing Record 258 of Set 6 | Pionerskiy
# Processing Record 259 of Set 6 | Hasaki
# Processing Record 260 of Set 6 | Eureka
# Processing Record 261 of Set 6 | Ancud
# Processing Record 262 of Set 6 | Yulara
#
#  City not found. Skipping...
#
# Processing Record 264 of Set 6 | Harper
# Processing Record 265 of Set 6 | Banda Aceh
# Processing Record 266 of Set 6 | Andilamena
# Processing Record 267 of Set 6 | Geraldton
# Processing Record 268 of Set 6 | Kununurra
# Processing Record 269 of Set 6 | Nyurba
#
#  City not found. Skipping...
#
# Processing Record 271 of Set 6 | Severo-Kuril'sk
# Processing Record 272 of Set 6 | Huambo
# Processing Record 273 of Set 6 | Uni
#
#  City not found. Skipping...
#
# Processing Record 275 of Set 6 | Finote Selam
# Processing Record 276 of Set 6 | Porto Velho
# Processing Record 277 of Set 6 | Eydhafushi
#
#  City not found. Skipping...
#
# Processing Record 279 of Set 6 | Slave Lake
# Processing Record 280 of Set 6 | Pangnirtung
# Processing Record 281 of Set 6 | Ust'-Abakan
# Processing Record 282 of Set 6 | Imbituba
# Processing Record 283 of Set 6 | San Patricio
# Processing Record 284 of Set 6 | Saint-François
#
#  City not found. Skipping...
#
# Processing Record 286 of Set 6 | Duku
#
#  City not found. Skipping...
#
#
#  City not found. Skipping...
#
# Processing Record 289 of Set 6 | Lagoa
# Processing Record 290 of Set 6 | Yumen
# Processing Record 291 of Set 6 | Atar
# Processing Record 292 of Set 6 | Suyo
# Processing Record 293 of Set 6 | Agadez
# Processing Record 294 of Set 6 | Belmonte
# Processing Record 295 of Set 6 | Imbatug
# Processing Record 296 of Set 6 | Soyo
# Processing Record 297 of Set 6 | Yangi Marg`ilon
# Processing Record 298 of Set 6 | Honningsvåg
# Processing Record 299 of Set 6 | Erzin
# Processing Record 300 of Set 6 | Cap Malheureux
# Processing Record 301 of Set 7 | Novikovo
# Processing Record 302 of Set 7 | Port Lincoln
#
#  City not found. Skipping...
#
# Processing Record 304 of Set 7 | Shelui
# Processing Record 305 of Set 7 | Pathein
# Processing Record 306 of Set 7 | Itarema
# Processing Record 307 of Set 7 | Vila Velha
# Processing Record 308 of Set 7 | Santa Cruz de la Sierra
# Processing Record 309 of Set 7 | Bilma
# Processing Record 310 of Set 7 | Aksay
# Processing Record 311 of Set 7 | Homer
#
#  City not found. Skipping...
#
# Processing Record 313 of Set 7 | Sorong
# Processing Record 314 of Set 7 | Mabamba
# Processing Record 315 of Set 7 | Changji
# Processing Record 316 of Set 7 | Sørland
# Processing Record 317 of Set 7 | Constitución
# Processing Record 318 of Set 7 | Matagami
# Processing Record 319 of Set 7 | Okha
# Processing Record 320 of Set 7 | Lupiro
# Processing Record 321 of Set 7 | Qaqortoq
# Processing Record 322 of Set 7 | Ekibastuz
# Processing Record 323 of Set 7 | Sulangan
# Processing Record 324 of Set 7 | Nevel'sk
# Processing Record 325 of Set 7 | Hanzhong
# Processing Record 326 of Set 7 | Bambous Virieux
# Processing Record 327 of Set 7 | Tchaourou
# Processing Record 328 of Set 7 | Kapit
# Processing Record 329 of Set 7 | Faanui
# Processing Record 330 of Set 7 | Cidreira
#
#  City not found. Skipping...
#
# Processing Record 332 of Set 7 | Vila Franca do Campo
# Processing Record 333 of Set 7 | Port Macquarie
# Processing Record 334 of Set 7 | Kalemie
# Processing Record 335 of Set 7 | Paciran
# Processing Record 336 of Set 7 | Januária
# Processing Record 337 of Set 7 | Parfino
# Processing Record 338 of Set 7 | Comoapan
# Processing Record 339 of Set 7 | Pachino
# Processing Record 340 of Set 7 | Kibaya
# Processing Record 341 of Set 7 | Sémbé
#
#  City not found. Skipping...
#
# Processing Record 343 of Set 7 | Kommunar
# Processing Record 344 of Set 7 | Ixtapa
# Processing Record 345 of Set 7 | Zhigansk
# Processing Record 346 of Set 7 | Nantucket
# Processing Record 347 of Set 7 | Sambava
# Processing Record 348 of Set 7 | Port Elizabeth
# Processing Record 349 of Set 7 | Hokitika
# Processing Record 350 of Set 7 | Las Palmas
# Processing Record 351 of Set 8 | Santa Cruz de Tenerife
# Processing Record 352 of Set 8 | Tiksi
# Processing Record 353 of Set 8 | Kumul
# Processing Record 354 of Set 8 | Illapel
# Processing Record 355 of Set 8 | Santa Lucía
# Processing Record 356 of Set 8 | Alexander City
#
#  City not found. Skipping...
#
# Processing Record 358 of Set 8 | Fort Nelson
# Processing Record 359 of Set 8 | Taltal
#
#  City not found. Skipping...
#
# Processing Record 361 of Set 8 | İslahiye
# Processing Record 362 of Set 8 | Roald
# Processing Record 363 of Set 8 | Muros
# Processing Record 364 of Set 8 | Tucuruí
# Processing Record 365 of Set 8 | Talnakh
# Processing Record 366 of Set 8 | Mogok
# Processing Record 367 of Set 8 | Nuevitas
# Processing Record 368 of Set 8 | Andijan
# Processing Record 369 of Set 8 | Pangkalanbuun
# Processing Record 370 of Set 8 | Yaan
# Processing Record 371 of Set 8 | Dunedin
# Processing Record 372 of Set 8 | Port-Gentil
# Processing Record 373 of Set 8 | Abhā
# Processing Record 374 of Set 8 | Alice Springs
# Processing Record 375 of Set 8 | Berlevåg
#
#  City not found. Skipping...
#
# Processing Record 377 of Set 8 | Aripuanã
# Processing Record 378 of Set 8 | Faya
# Processing Record 379 of Set 8 | Poum
#
#  City not found. Skipping...
#
# Processing Record 381 of Set 8 | Kiunga
# Processing Record 382 of Set 8 | Atambua
# Processing Record 383 of Set 8 | Ostrovnoy
# Processing Record 384 of Set 8 | Cockburn Town
# Processing Record 385 of Set 8 | São João da Barra
# Processing Record 386 of Set 8 | Calamar
# Processing Record 387 of Set 8 | Wairoa
# Processing Record 388 of Set 8 | Whitehorse
# Processing Record 389 of Set 8 | Kamiiso
# Processing Record 390 of Set 8 | Province of Groningen
# Processing Record 391 of Set 8 | Meadow Lake
# Processing Record 392 of Set 8 | Ossora
# Processing Record 393 of Set 8 | Lac du Bonnet
# Processing Record 394 of Set 8 | ‘Āhuimanu
# Processing Record 395 of Set 8 | Great Falls
# Processing Record 396 of Set 8 | Vestmannaeyjar
# Processing Record 397 of Set 8 | Lakatoro
#
#  City not found. Skipping...
#
# Processing Record 399 of Set 8 | Gold Coast
# Processing Record 400 of Set 8 | Waipawa
#
#  City not found. Skipping...
#
# Processing Record 402 of Set 9 | Solnechnyy
# Processing Record 403 of Set 9 | Kenora
# Processing Record 404 of Set 9 | Trelew
# Processing Record 405 of Set 9 | Allāpalli
# Processing Record 406 of Set 9 | Cabra
# Processing Record 407 of Set 9 | Rodrigues Alves
# Processing Record 408 of Set 9 | Tiznit Province
# Processing Record 409 of Set 9 | Boguchany
# Processing Record 410 of Set 9 | Adré
# Processing Record 411 of Set 9 | Laas
# Processing Record 412 of Set 9 | Hamilton
# Processing Record 413 of Set 9 | Vostok
# Processing Record 414 of Set 9 | Milverton
# Processing Record 415 of Set 9 | Selishche
# Processing Record 416 of Set 9 | Orán
# Processing Record 417 of Set 9 | Benguela
# Processing Record 418 of Set 9 | Tilichiki
# Processing Record 419 of Set 9 | Havøysund
# Processing Record 420 of Set 9 | Teknāf
# Processing Record 421 of Set 9 | Salinópolis
# Processing Record 422 of Set 9 | Lorengau
# Processing Record 423 of Set 9 | Port Hedland
# Processing Record 424 of Set 9 | Northam
# Processing Record 425 of Set 9 | Loandjili
# Processing Record 426 of Set 9 | Salé
# Processing Record 427 of Set 9 | Pincher Creek
# Processing Record 428 of Set 9 | Tirat Carmel
# Processing Record 429 of Set 9 | Abu Dhabi
#
#  City not found. Skipping...
#
# Processing Record 431 of Set 9 | Fare
# Processing Record 432 of Set 9 | Khawhai
# Processing Record 433 of Set 9 | Córdoba
# Processing Record 434 of Set 9 | Abhar
# Processing Record 435 of Set 9 | La Asuncion
# Processing Record 436 of Set 9 | Nishihara
# Processing Record 437 of Set 9 | Kortkeros
# Processing Record 438 of Set 9 | Oodweyne
# Processing Record 439 of Set 9 | Steinbach am Taunus
# Processing Record 440 of Set 9 | Plettenberg Bay
# Processing Record 441 of Set 9 | Zhangjiakou Shi Xuanhua Qu
#
#  City not found. Skipping...
#
#
#  City not found. Skipping...
#
# Processing Record 444 of Set 9 | Baykalovo
# Processing Record 445 of Set 9 | Kupang
#
#  City not found. Skipping...
#
# Processing Record 447 of Set 9 | Hervey Bay
# Processing Record 448 of Set 9 | Price
# Processing Record 449 of Set 9 | Santiago
# Processing Record 450 of Set 9 | Drumheller
# Processing Record 451 of Set 10 | Ciamis
# Processing Record 452 of Set 10 | Sandpoint
# Processing Record 453 of Set 10 | Maniitsoq
# Processing Record 454 of Set 10 | Sechura
#
#  City not found. Skipping...
#
# Processing Record 456 of Set 10 | Saint-Louis
#
#  City not found. Skipping...
#
# Processing Record 458 of Set 10 | Sola
# Processing Record 459 of Set 10 | Coffs Harbour
# Processing Record 460 of Set 10 | Leh
# Processing Record 461 of Set 10 | Sheridan
# Processing Record 462 of Set 10 | Makkah al Mukarramah
#
#  City not found. Skipping...
#
#
#  City not found. Skipping...
#
# Processing Record 465 of Set 10 | Ugoofaaru
# Processing Record 466 of Set 10 | Seoul
# Processing Record 467 of Set 10 | Clyde River
# Processing Record 468 of Set 10 | Nizwá
# Processing Record 469 of Set 10 | Camaná
# Processing Record 470 of Set 10 | Tsimmerbude
# Processing Record 471 of Set 10 | Ipilan
# Processing Record 472 of Set 10 | Morón
# Processing Record 473 of Set 10 | Tutóia
# Processing Record 474 of Set 10 | Souillac
# Processing Record 475 of Set 10 | Tshane
# Processing Record 476 of Set 10 | Tarko-Sale
# Processing Record 477 of Set 10 | Truro
# Processing Record 478 of Set 10 | Shumerlya
# Processing Record 479 of Set 10 | Pombas
# Processing Record 480 of Set 10 | San Andrés
# Processing Record 481 of Set 10 | Klaksvík
# Processing Record 482 of Set 10 | Launceston
# Processing Record 483 of Set 10 | Ust'-Omchug
# Processing Record 484 of Set 10 | Bintulu
# Processing Record 485 of Set 10 | Guayaramerín
# Processing Record 486 of Set 10 | Fauske
#
#  City not found. Skipping...
#
# Processing Record 488 of Set 10 | Portoferraio
#
#  City not found. Skipping...
#
# Processing Record 490 of Set 10 | Ambilobe
# Processing Record 491 of Set 10 | Londoko
# Processing Record 492 of Set 10 | Maningrida
# Processing Record 493 of Set 10 | Severo-Yeniseyskiy
# Processing Record 494 of Set 10 | Quatre Cocos
# Processing Record 495 of Set 10 | Saint-Pierre
# Processing Record 496 of Set 10 | Yambio
# Processing Record 497 of Set 10 | Vanimo
# Processing Record 498 of Set 10 | Aasiaat
# Processing Record 499 of Set 10 | Ngunguru
# Processing Record 500 of Set 10 | Oktyabr'skiy
# Processing Record 501 of Set 11 | Piran
# Processing Record 502 of Set 11 | Kamenka
# Processing Record 503 of Set 11 | Wawa
# Processing Record 504 of Set 11 | Diébougou
# Processing Record 505 of Set 11 | Bella Vista
# Processing Record 506 of Set 11 | Rørvik
# Processing Record 507 of Set 11 | Deputatsky
# Processing Record 508 of Set 11 | Hay River
# Processing Record 509 of Set 11 | Hlukhiv
# Processing Record 510 of Set 11 | Boden
#
#  City not found. Skipping...
#
# Processing Record 512 of Set 11 | Avera
# Processing Record 513 of Set 11 | Charters Towers
# Processing Record 514 of Set 11 | Halifax
# Processing Record 515 of Set 11 | Benghazi
# Processing Record 516 of Set 11 | Sumbe
# Processing Record 517 of Set 11 | Tignère
# Processing Record 518 of Set 11 | Kavaratti
#
#  City not found. Skipping...
#
# Processing Record 520 of Set 11 | Searcy
# Processing Record 521 of Set 11 | Henties Bay
# Processing Record 522 of Set 11 | Dharmābād
# Processing Record 523 of Set 11 | Batagay-Alyta
# Processing Record 524 of Set 11 | Karpathos
# Processing Record 525 of Set 11 | Al Bardīyah
# Processing Record 526 of Set 11 | Lyman
# Processing Record 527 of Set 11 | Tabou
# Processing Record 528 of Set 11 | Sault Ste. Marie
# Processing Record 529 of Set 11 | Vao
# Processing Record 530 of Set 11 | Ponta Delgada
# Processing Record 531 of Set 11 | Samsun Province
# Processing Record 532 of Set 11 | Glendive
# Processing Record 533 of Set 11 | Koumac
#
#  City not found. Skipping...
#
# Processing Record 535 of Set 11 | Chërnaya Kholunitsa
# Processing Record 536 of Set 11 | Fortuna
# Processing Record 537 of Set 11 | Mesyagutovo
# Processing Record 538 of Set 11 | Yalta
# Processing Record 539 of Set 11 | Porto-Novo
#
#  City not found. Skipping...
#
# Processing Record 541 of Set 11 | Mariakani
# Processing Record 542 of Set 11 | Nsanje
# Processing Record 543 of Set 11 | Hirara
# Processing Record 544 of Set 11 | Rūdbār
# Processing Record 545 of Set 11 | Maceió
# Processing Record 546 of Set 11 | Yakeshi
# Processing Record 547 of Set 11 | Nelson Bay
# Processing Record 548 of Set 11 | Salta
# Processing Record 549 of Set 11 | Kismayo
# Processing Record 550 of Set 11 | Iquitos
# Processing Record 551 of Set 12 | Odoyev
#
#  City not found. Skipping...
#
# Processing Record 553 of Set 12 | Itigi
# Processing Record 554 of Set 12 | Goma
# Processing Record 555 of Set 12 | Druzhnaya Gorka
# Processing Record 556 of Set 12 | Wewak
# Processing Record 557 of Set 12 | Kalmunai
# Processing Record 558 of Set 12 | Half Moon Bay
# Processing Record 559 of Set 12 | Te Anau
# Processing Record 560 of Set 12 | Amahai
# Processing Record 561 of Set 12 | Estelle
# Processing Record 562 of Set 12 | Iraquara
# Processing Record 563 of Set 12 | Valparaíso
# Processing Record 564 of Set 12 | Bacolod City
# Processing Record 565 of Set 12 | Alofi
# Processing Record 566 of Set 12 | Turukhansk
# Processing Record 567 of Set 12 | Muyezerskiy
#
#  City not found. Skipping...
#
# Processing Record 569 of Set 12 | Barras
# Processing Record 570 of Set 12 | Durrës
# Processing Record 571 of Set 12 | West Plains
# Processing Record 572 of Set 12 | Athabasca
# Processing Record 573 of Set 12 | Balīlā
# Processing Record 574 of Set 12 | Acaraú
# Processing Record 575 of Set 12 | Honiara
# Processing Record 576 of Set 12 | San Vicente
# Processing Record 577 of Set 12 | Borazjan
# Processing Record 578 of Set 12 | Acapulco de Juárez
# Processing Record 579 of Set 12 | Kildare
# Processing Record 580 of Set 12 | Puerto Madryn
# Processing Record 581 of Set 12 | Newport
# Processing Record 582 of Set 12 | Arman'
# Processing Record 583 of Set 12 | Fuzhou
# Processing Record 584 of Set 12 | Arlit
# Processing Record 585 of Set 12 | Magdalena
# Processing Record 586 of Set 12 | Leshukonskoye
# Processing Record 587 of Set 12 | Grindavik
# Processing Record 588 of Set 12 | Saint George
# Processing Record 589 of Set 12 | Kisaran
# Processing Record 590 of Set 12 | Nakamura
#
#  City not found. Skipping...
#
# Processing Record 592 of Set 12 | Egvekinot
# Processing Record 593 of Set 12 | Teya
# Processing Record 594 of Set 12 | Ballina
# Processing Record 595 of Set 12 | Stokmarknes
# Processing Record 596 of Set 12 | Smithers
# Processing Record 597 of Set 12 | Chistogorskiy
# Processing Record 598 of Set 12 | Cairns
# Processing Record 599 of Set 12 | Olafsvik
# Processing Record 600 of Set 12 | Hualmay
# Processing Record 601 of Set 13 | Skibbereen
# Processing Record 602 of Set 13 | Bilibino
# Processing Record 603 of Set 13 | Omboué
# Processing Record 604 of Set 13 | Butembo
# Processing Record 605 of Set 13 | North Bend
# Processing Record 606 of Set 13 | Saint-Augustin
# Processing Record 607 of Set 13 | Ol'ga
# Processing Record 608 of Set 13 | Gizo Government Station
# Processing Record 609 of Set 13 | Bozoum
# Processing Record 610 of Set 13 | Mikhaylovka
# Processing Record 611 of Set 13 | Kaseda-shirakame
# Processing Record 612 of Set 13 | Lagan
#
#  City not found. Skipping...
#
# Processing Record 614 of Set 13 | Karasjok
# Processing Record 615 of Set 13 | Port Augusta
# Processing Record 616 of Set 13 | Pervomayskiy
# Processing Record 617 of Set 13 | Puro
# Processing Record 618 of Set 13 | Broken Hill
# Processing Record 619 of Set 13 | Koungou
#
#  City not found. Skipping...
#
#
#  City not found. Skipping...
#
# Processing Record 622 of Set 13 | Salalah
# Processing Record 623 of Set 13 | Marabu
#
#  City not found. Skipping...
#
# Processing Record 625 of Set 13 | Diffa
# Processing Record 626 of Set 13 | Vlagtwedde
# Processing Record 627 of Set 13 | Talcahuano
# Processing Record 628 of Set 13 | Port-Cartier
# Processing Record 629 of Set 13 | Onguday
# Processing Record 630 of Set 13 | Quartucciu
# Processing Record 631 of Set 13 | Alexandria
# Processing Record 632 of Set 13 | Blagoyevo
# Processing Record 633 of Set 13 | Evensk
# Processing Record 634 of Set 13 | Sur
# Processing Record 635 of Set 13 | Boissevain
# Processing Record 636 of Set 13 | Conakry
# Processing Record 637 of Set 13 | Tobermory
# Processing Record 638 of Set 13 | Plymouth
# Processing Record 639 of Set 13 | Huilong
# Processing Record 640 of Set 13 | Indramayu
#
#  City not found. Skipping...
#
# Processing Record 642 of Set 13 | Aykhal
# Processing Record 643 of Set 13 | Paamiut
# Processing Record 644 of Set 13 | Porbandar
#
#  City not found. Skipping...
#
# Processing Record 646 of Set 13 | Tambun
# Processing Record 647 of Set 13 | Oparino
# Processing Record 648 of Set 13 | Touros
# Processing Record 649 of Set 13 | Papagaios
# Processing Record 650 of Set 13 | Filingué
# Processing Record 651 of Set 14 | Tynda
# Processing Record 652 of Set 14 | Ciudad Bolivar
# Processing Record 653 of Set 14 | Merauke
# Processing Record 654 of Set 14 | Quelimane
# Processing Record 655 of Set 14 | Korla
# Processing Record 656 of Set 14 | Panabá
# Processing Record 657 of Set 14 | Östersund
# Processing Record 658 of Set 14 | Wajima
# Processing Record 659 of Set 14 | Uruçuí
# Processing Record 660 of Set 14 | Shimoda
# Processing Record 661 of Set 14 | Urazovo
#
#  City not found. Skipping...
#
# Processing Record 663 of Set 14 | Kopavogur
# Processing Record 664 of Set 14 | Santa Maria
# Processing Record 665 of Set 14 | Bud
# Processing Record 666 of Set 14 | Province of Mantua
# Processing Record 667 of Set 14 | Boende
# Processing Record 668 of Set 14 | Singaraja
# Processing Record 669 of Set 14 | Husavik
#
#  City not found. Skipping...
#
# Processing Record 671 of Set 14 | Nouadhibou
# Processing Record 672 of Set 14 | Tashara
# Processing Record 673 of Set 14 | Sibolga
# Processing Record 674 of Set 14 | Pitimbu
# Processing Record 675 of Set 14 | Deming
# Processing Record 676 of Set 14 | Lazo
# Processing Record 677 of Set 14 | Cape Canaveral
# Processing Record 678 of Set 14 | Strezhevoy
# Processing Record 679 of Set 14 | Sunrise Manor
# Processing Record 680 of Set 14 | Zhezkazgan
# Processing Record 681 of Set 14 | Broome
# Processing Record 682 of Set 14 | Inhambane
# Processing Record 683 of Set 14 | Lucapa
# Processing Record 684 of Set 14 | Itupiranga
# Processing Record 685 of Set 14 | Andenes
# Processing Record 686 of Set 14 | Bamberg
# Processing Record 687 of Set 14 | Zhigalovo
# Processing Record 688 of Set 14 | Fuerte Olimpo
# Processing Record 689 of Set 14 | Mayo
# Processing Record 690 of Set 14 | Noyabrsk
# Processing Record 691 of Set 14 | Morehead
# Processing Record 692 of Set 14 | Bariloche
# Processing Record 693 of Set 14 | Alyangula
# Processing Record 694 of Set 14 | Fairbanks
# Processing Record 695 of Set 14 | Kingaroy
# Processing Record 696 of Set 14 | San Quintín
# Processing Record 697 of Set 14 | Havelock
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#displaying DF
df_cities
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         atuona  -9.8000 -139.0333     77.67      74.0        16.0
# 1     miles city  46.4083 -105.8406     47.52      76.0         1.0
# 2        vaitupu      NaN       NaN       NaN       NaN         NaN
# 3         kampot  10.6167  104.1833     83.17      76.0        98.0
# 4          kuche      NaN       NaN       NaN       NaN         NaN
# ..           ...      ...       ...       ...       ...         ...
# 692    alyangula -13.8483  136.4192     87.67      62.0        59.0
# 693    fairbanks  64.8378 -147.7164     24.76      90.0        75.0
# 694     kingaroy -26.5333  151.8333     64.44     100.0        75.0
# 695  san quintin  30.4833 -115.9500     61.56      89.0        31.0
# 696     havelock  34.8791  -76.9013     75.18      91.0       100.0
#
#      Wind Speed Country          Date
# 0         14.72      PF  1.635150e+09
# 1         16.11      US  1.635150e+09
# 2           NaN     NaN           NaN
# 3         10.04      KH  1.635150e+09
# 4           NaN     NaN           NaN
# ..          ...     ...           ...
# 692       10.36      AU  1.635151e+09
# 693        0.00      US  1.635151e+09
# 694        8.05      AU  1.635151e+09
# 695        5.44      MX  1.635151e+09
# 696        7.29      US  1.635151e+09
#
# [697 rows x 9 columns]

# %%
df_cities.to_csv("output.csv", index=True, index_label="City No.")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
df_cities["Humidity"]
# Out:
# 0       74.0
# 1       76.0
# 2        NaN
# 3       76.0
# 4        NaN
#        ...
# 692     62.0
# 693     90.0
# 694    100.0
# 695     89.0
# 696     91.0
# Name: Humidity, Length: 697, dtype: float64

# %%
#  Get the indices of cities that have humidity over 100%
df_humidity_100 = df_cities.loc[df_cities["Humidity"] > 100, :]

df_humidity_100

#Therefore no cities where the humidity is greater than 100%
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# df_cities_cleaned = df_cities.drop(df_humidity_100)

# df_cities_cleaned

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitudes = pd.to_numeric(df_cities["Lat"])
temperatures = pd.to_numeric(df_cities["Max Temp"])

#generating scatter plot lat vs temperature
plt.figure(figsize=(8, 6), dpi=80) #re-sizing the plot 
plt.scatter(latitudes, temperatures, marker="o", facecolors="blue", edgecolors="black")

#addings title, x & y labels and grid to the scatter plot
plt.title("City Latitude vs. Max Temperature (23/10/21)")
plt.ylabel("Max Temperature (deg C)")
plt.xlabel("Latitude")
plt.grid()

#saving png image file in the folder
plt.savefig("Fig1.png")
#displaying scatter plot
plt.show()

##analysis
#Temperatures increase moving closer towards the equator. 
#Some cities in the Northern hemisphere experience lower temperatures (in the negatives) due to their 
#location being closer to the north pole

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#generating scatter plot lat vs temperature
humidity = df_cities["Humidity"]

plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(latitudes, humidity, marker="o", facecolors="blue", edgecolors="black")

plt.title("City Latitude vs. Humidity (23/10/21)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()

plt.savefig("Fig2.png")
plt.show()

#analysis
#More cities have humidity 60% or higher. 
#All cities at the equator (0 deg) latitude have humidity 60% or higher
#More cities have lower humidity levels at the tropics

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Generating scatter plot. Steps - same as above. 
cloudiness = pd.to_numeric(df_cities["Cloudiness"])

plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(latitudes, cloudiness, marker="o", facecolors="blue", edgecolors="black")

plt.title("City Latitude vs. Cloudiness (23/10/21)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()

plt.savefig("Fig3.png")
plt.show()

##analysis
#At 0 deg lat, more cities  have 100% cloudiness 
#cities located at the tropics have lower cloudiness percentages
#again cities far in the northern hemisphere (60-80deg) tend to have higher percentage of cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
from matplotlib.pyplot import figure

#generating scatter plot lat vs temperature
winds = pd.to_numeric(df_cities["Wind Speed"])

plt.figure(figsize=(8, 6), dpi=80)
plt.scatter(latitudes, winds, marker="o", facecolors="blue", edgecolors="black")

plt.title("City Latitude vs. Windspeed (23/10/21)")

plt.ylabel("Windspeed (m/s)")
plt.xlabel("Latitude")
plt.grid()

plt.savefig("Fig4.png")
plt.show()

#analysis
#

# %% [markdown]
# ## Linear Regression

# %%
#copying dataframe this analysis 
df_cities_hemispheres = df_cities.copy().dropna()

#adding "Hemisphere" column 
df_cities_hemispheres["Hemisphere"] = ""

df_cities_hemispheres
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          atuona  -9.8000 -139.0333     77.67      74.0        16.0
# 1      miles city  46.4083 -105.8406     47.52      76.0         1.0
# 3          kampot  10.6167  104.1833     83.17      76.0        98.0
# 5    staryy nadym  65.6118   72.6842     26.55      79.0        84.0
# 6       busselton -33.6500  115.3333     60.04      52.0        95.0
# ..            ...      ...       ...       ...       ...         ...
# 692     alyangula -13.8483  136.4192     87.67      62.0        59.0
# 693     fairbanks  64.8378 -147.7164     24.76      90.0        75.0
# 694      kingaroy -26.5333  151.8333     64.44     100.0        75.0
# 695   san quintin  30.4833 -115.9500     61.56      89.0        31.0
# 696      havelock  34.8791  -76.9013     75.18      91.0       100.0
#
#      Wind Speed Country          Date Hemisphere
# 0         14.72      PF  1.635150e+09
# 1         16.11      US  1.635150e+09
# 3         10.04      KH  1.635150e+09
# 5          9.28      RU  1.635150e+09
# 6         16.06      AU  1.635150e+09
# ..          ...     ...           ...        ...
# 692       10.36      AU  1.635151e+09
# 693        0.00      US  1.635151e+09
# 694        8.05      AU  1.635151e+09
# 695        5.44      MX  1.635151e+09
# 696        7.29      US  1.635151e+09
#
# [635 rows x 10 columns]

# %%
for index, row in df_cities_hemispheres.iterrows():
    if row["Lat"] > 0:
        df_cities_hemispheres.loc[index,"Hemisphere"]= "Northern Hemisphere"
    elif row["Lat"] < 0:
        df_cities_hemispheres.loc[index,"Hemisphere"]= "Southern Hemisphere"
    elif row["Lat"] == 0:
        df_cities_hemispheres.loc[index,"Hemisphere"]= "Equator" 
    
df_cities_hemispheres
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          atuona  -9.8000 -139.0333     77.67      74.0        16.0
# 1      miles city  46.4083 -105.8406     47.52      76.0         1.0
# 3          kampot  10.6167  104.1833     83.17      76.0        98.0
# 5    staryy nadym  65.6118   72.6842     26.55      79.0        84.0
# 6       busselton -33.6500  115.3333     60.04      52.0        95.0
# ..            ...      ...       ...       ...       ...         ...
# 692     alyangula -13.8483  136.4192     87.67      62.0        59.0
# 693     fairbanks  64.8378 -147.7164     24.76      90.0        75.0
# 694      kingaroy -26.5333  151.8333     64.44     100.0        75.0
# 695   san quintin  30.4833 -115.9500     61.56      89.0        31.0
# 696      havelock  34.8791  -76.9013     75.18      91.0       100.0
#
#      Wind Speed Country          Date           Hemisphere
# 0         14.72      PF  1.635150e+09  Southern Hemisphere
# 1         16.11      US  1.635150e+09  Northern Hemisphere
# 3         10.04      KH  1.635150e+09  Northern Hemisphere
# 5          9.28      RU  1.635150e+09  Northern Hemisphere
# 6         16.06      AU  1.635150e+09  Southern Hemisphere
# ..          ...     ...           ...                  ...
# 692       10.36      AU  1.635151e+09  Southern Hemisphere
# 693        0.00      US  1.635151e+09  Northern Hemisphere
# 694        8.05      AU  1.635151e+09  Southern Hemisphere
# 695        5.44      MX  1.635151e+09  Northern Hemisphere
# 696        7.29      US  1.635151e+09  Northern Hemisphere
#
# [635 rows x 10 columns]

# %%
#df for NH
northern_hemisphere = df_cities_hemispheres.loc[df_cities_hemispheres["Hemisphere"]=="Northern Hemisphere", :]
#checking distribution of sitives along the longitudes
count1 = northern_hemisphere["City"].count()
print(f"There are {count1} cities are in the Northern Hemisphere ")

#df for SH
southern_hemisphere = df_cities_hemispheres.loc[df_cities_hemispheres["Hemisphere"]=="Southern Hemisphere", :]
count2 = southern_hemisphere["City"].count()
print(f"There are {count2} cities are in the Southern Hemisphere ")
# Out:
# There are 426 cities are in the Northern Hemisphere
# There are 209 cities are in the Southern Hemisphere

# %%
temp_NH = northern_hemisphere["Max Temp"]
temp_SH = southern_hemisphere["Max Temp"]
lat_NH = northern_hemisphere["Lat"]
lat_SH = southern_hemisphere["Lat"]
humidity_NH = northern_hemisphere["Humidity"]
humidity_SH = southern_hemisphere["Humidity"]
cloudiness_NH = northern_hemisphere["Cloudiness"]
cloudiness_SH = southern_hemisphere["Cloudiness"]
windspeed_NH = northern_hemisphere["Wind Speed"]
windspeed_SH = southern_hemisphere["Wind Speed"]

# %%
import scipy.stats as st

def linear_regression(x_value,y_value,x_label,y_label,title):
    correlation = st.pearsonr(x_value,y_value)
    
    slope, intercept, r_value, p_value, std_error = st.linregress(x_value, y_value)
    print(f"The r-value is {r_value}")

    regress_values = x_value * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.figure(figsize=(8, 6), dpi=80)
    plt.scatter(x_value,y_value, marker="o", facecolors="blue", edgecolors="black")
    plt.plot(x_value,regress_values,"r-")
    plt.annotate(line_eq,(min(x_value),min(y_value)),fontsize=20,color="red")

    plt.xlabel(f"{x_label}")
    plt.ylabel(f"{y_label}")
    plt.title(f"{title}")

    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_value = lat_NH
y_value = temp_NH
x_label = "Latitude" 
y_label = "Max Temp"
title = "Max Temp vs. Latitude Linear Regression for Northern Hemisphere"

linear_regression(x_value,y_value,x_label,y_label,title)

#linear regression is modelling negative correlation - decrease in lat -> increase in temp
#moving from north pole to the equator, temperature increases
# Out:
# The r-value is -0.9019950555341296

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_value = lat_SH
y_value = temp_SH
x_label = "Latitude"
y_label = "Max Temp"
title = "Max Temp vs. Latitude Linear Regression for Southern Hemisphere"

linear_regression(x_value,y_value,x_label,y_label,title)

#linear regression is modelling positive correlation - increase in lat -> increase in temp
#moving from south pole to the equator, temperature increases
# Out:
# The r-value is 0.7298617514306327

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value = lat_NH
y_value = humidity_NH
x_label = "Humidity"
y_label = "Latitude"
title = "Humidity (%) vs. Latitude Linear Regression"

linear_regression(x_value,y_value,x_label,y_label,title)

#linear regression is modelling a flat line
#conclusion - no correlation between humidity and lat
# Out:
# The r-value is 0.2579662899189715

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value = lat_SH
y_value = humidity_SH
x_label = "Latitude"
y_label = "Humidity (%)"
title = "Max Temp vs. Latitude Linear Regression"

linear_regression(x_value,y_value,x_label,y_label,title)

#same as for northern hemisphere
#linear regression is modelling a flat line and low r-value
#conclusion - no correlation between humidity and lat
# Out:
# The r-value is 0.07986735087604399

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value = lat_NH
y_value = cloudiness_NH
x_label = "Latitude"
y_label = "Cloudiness (%)"
title = "Cloudiness (%) vs. Latitude Linear Regression"

linear_regression(x_value,y_value,x_label,y_label,title)

#linear regression is modelling a flat line and low r-value
#conclusion - no correlation between cloudiness and lat
# Out:
# The r-value is 0.0951919662841778

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value = lat_SH
y_value = cloudiness_SH
x_label = "Latitude"
y_label = "Cloudiness (%)"
title = "Cloudiness (%) vs. Latitude Linear Regression"

linear_regression(x_value,y_value,x_label,y_label,title)

#linear regression is modelling a flat line and low r-value
#conclusion - no correlation between cloudiness and lat
# Out:
# The r-value is 0.22530166626664752

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value = lat_NH
y_value = windspeed_NH
x_label = "Latitude"
y_label = "Wind Speed (mph)"
title = "Wind Speed (mph) vs. Latitude Linear Regression"

linear_regression(x_value,y_value,x_label,y_label,title)

#linear regression is modelling a flat line and low r-value
#conclusion - no correlation between windspeed and lat
# Out:
# The r-value is 0.09455232640467186

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value = lat_SH
y_value = windspeed_SH
x_label = "Max Temp"
y_label = "Wind Speed (mph)"
title = "Wind Speed (mph) vs. Latitude Linear Regression"

linear_regression(x_value,y_value,x_label,y_label,title)

#linear regression is modelling a flat line and low r-value
#conclusion - no correlation between windspeed and lat
# Out:
# The r-value is -0.3245459673349062
